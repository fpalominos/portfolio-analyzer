# %% [markdown]
# finnhub_quote

# %%
from portfolio_analyzer.models.finnhub_quote import FinnhubQuote

# data = {"c":206.94,"d":6.19,"dp":3.0834,"h":207.4,"l":196.85,"o":199.51,"pc":200.75,"t":1785772216}

data = {"c": 0, "d": None, "dp": None, "h": 0, "l": 0, "o": 0, "pc": 0, "t": 0}

quote = FinnhubQuote.model_validate(data)

r = any(
    (quote.current_price,
     quote.high
     )
)
print(quote)
# Out:
# current_price=0.0 high=0.0 low=0.0 open=0.0 previous_close=0.0
